# %% [markdown]
# # Gather Data
#
# The data has been made available by Motivate International Inc and it can be found [here](https://divvy-tripdata.s3.amazonaws.com/index.html).

# %%
# import modules
import os
import numpy as np
import pandas as pd

# %%
# assign path
path, dirs, files = next(os.walk("data/csv/"))
file_count = len(files)

# %% [markdown]
# #### Method 1
# Read the csv files into a dataframe.<br>
# This method creates a list for each file. This method would't be used.

# %% [raw]
# # create empty list
# dataframes_list = []
#
# # append datasets to the list
# for i in range(file_count):
#     df = pd.read_csv("data/csv/"+files[i])
#     dataframes_list.append(df)
#
# # display datasets
# for dataset in dataframes_list:
#     display(dataset)

# %% [markdown]
# #### Method 2
# Read the csv files into a dataframe.<br>
# This method reads all the csv files into one dataframe

# %%
# create empty list
entire_df = []
 
# append datasets to the list
for i in range(file_count):
    entire_df.append(pd.read_csv("data/csv/"+files[i]))
     
df = pd.concat(entire_df, ignore_index=True)
df.head()
# Out:
#                   ride_id  rideable_type           started_at  \
# 0        E19E6F1B8D4C42ED  electric_bike  2021-01-23 16:14:19
# 1        DC88F20C2C55F27F  electric_bike  2021-01-27 18:43:08
# 2        EC45C94683FE3F27  electric_bike  2021-01-21 22:35:54
# 3        4FA453A75AE377DB  electric_bike  2021-01-07 13:31:13
# 4        BE5E8EB4E7263A0B  electric_bike  2021-01-23 02:24:02
# ...                   ...            ...                  ...
# 5595058  847431F3D5353AB7  electric_bike       12/12/21 13:36
# 5595059  CF407BBC3B9FAD63  electric_bike        12/6/21 19:37
# 5595060  60BB69EBF5440E92  electric_bike        12/2/21 08:57
# 5595061  C414F654A28635B8  electric_bike       12/13/21 09:00
# 5595062  37AC57E34B2E7E97   classic_bike       12/13/21 08:45
#
#                     ended_at           start_station_name start_station_id  \
# 0        2021-01-23 16:24:44   California Ave & Cortez St            17660
# ...

# %% [markdown]
# Save the dataframe into a csv file

# %%
df.to_csv('data/raw_bike_data.csv', index=False)
